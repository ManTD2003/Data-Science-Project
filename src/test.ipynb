# %%
from bertopic import BERTopic
topic_model = BERTopic.load('/home/duc-chung/work/20241/DataScience/Data-Science-Project/src/fitted_model')

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                               Name  \
# 0       -1   4395                        -1_,_giao_đóng_gói_cẩn_thận
# 1        0    318                                     0_2_hộp_)_viên
# 2        1    314                     1_Ok Ok Ok Ok_Okay Ok_Ok_Aa Ok
# 3        2    312                       2_ok ok ,_Ship ok_ok chết_re
# 4        3    154                3_san pham_tot_chat luong_done well
# ..     ...    ...                                                ...
# 113    112     17  112_Thơm mùi_Thơm dễ_chịu Thơm dễ_chịu_mùi dễ_...
# 114    113     16  113_góc làm_việc_gắt sản_phẩm mùi_phòng góc_nh...
# 115    114     16  114_chất_lượng Hàng chất_lượng_Giao nhanh_chón...
# 116    115     16      115_Tạm_Tạm Tạm_Tạm Tạm_đc Tạm_Tạm Tạm Tạm_dc
# 117    116     16              116_bồn_rửa_. bể_phốt_, lồng máy_giặt
#
#                                         Representation  \
# 0    [,, giao, đóng_gói, cẩn_thận, chất_lượng, ? ?,...
# 1    [2, hộp, ), viên, hàng, . mua, tặng, chai, sử_...
# 2    [Ok Ok Ok Ok, Okay Ok, Ok, Aa Ok, Ok Ok Ok Anc...
# 3    [ok ok ,, Ship ok, ok chết, re, . Ship, ổn, ok...
# 4    [san pham, tot, chat luong, done well, giao ha...
# ..                                                 ...
# 113  [Thơm mùi, Thơm dễ_chịu Thơm dễ_chịu, mùi dễ_c...
# 114  [góc làm_việc, gắt sản_phẩm mùi, phòng góc, nh...
# 115  [chất_lượng Hàng chất_lượng, Giao nhanh_chóng,...
# 116  [Tạm, Tạm Tạm, Tạm Tạm_đc Tạm, Tạm Tạm Tạm_dc,...
# 117  [bồn, rửa, . bể_phốt, , lồng máy_giặt, - sáng_...
#
#                                    Representative_Docs
# 0    [Giao hàng ,, Giao hàng , đóng_gói cẩn_thận . ...
# 1    [hài_lòng đơn hàng - mua 1 chai 2L hương chanh...
# 2                                         [Ok, Ok, Ok]
# 3                             [ok, ok ok, ok ok ok ok]
# 4    [chat luong tot, chat luong tot, chat luong sa...
# ..                                                 ...
# 113         [Thơm dễ_chịu, Thơm dễ_chịu, Thơm dễ_chịu]
# 114  [sản_phẩm thơm lắm, sản_phẩm thơm, sản_phẩm thơm]
# 115  [Hàng chất_lượng, Hàng chất_lượng, Hàng chất_l...
# 116                                    [Tạm, Tạm, Tạm]
# 117  [rửa máy rửa_bát sạch , đắt, Sản_phẩm tẩy vết ...
#
# [118 rows x 5 columns]

# %%
from preprocessing import preprocess_text
from utils import load_raw_data_to_list_comment

docs = load_raw_data_to_list_comment('/home/duc-chung/work/20241/DataScience/Data-Science-Project/tiki/raw/cham-soc-nha-cua.csv')
processed_docs = preprocess_text(docs)

# %%
processed_docs

# %%
topic_model.visualize_topics()

# %%
from utils import load_raw_data_to_list_comment, extract_all_topics_data
docs = load_raw_data_to_list_comment('/home/duc-chung/work/20241/DataScience/Data-Science-Project/tiki/raw/cham-soc-nha-cua.csv')
# docs
# cleaned_docs = preprocess_text(docs)

# %%
topic_data = extract_all_topics_data(topic_model)

# %%
import json
topic_data
with open('/home/duc-chung/work/20241/DataScience/Data-Science-Project/src/out_put.json', "w", encoding="utf-8") as f:
    json.dump(topic_data, f, ensure_ascii=False, indent=4)
