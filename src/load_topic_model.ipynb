# %%
from bertopic import BERTopic
topic_model = BERTopic.load('/home/duc-chung/work/20241/DataScience/Data-Science-Project/src/fitted_bertopic_model')

# %%
print(topic_model.get_topic_info())
# Out:
#      Topic  Count                                               Name  \
# 0       -1   4551  -1_đóng gói cẩn thận_cẩn thận ,_cẩn thận_rửa chén
# 1        0    661                        0_ok_ok ok_ok ok ok_ok good
# 2        1    446             1_tiki giao_đóng gói_tặng kèm_đơn hàng
# 3        2    125               2_good_good good_fast good_cool good
# 4        3    122   3_! hài lòng_tuyệt vời !_ngon tuyệt !_hài lòng !
# ..     ...    ...                                                ...
# 96      95     17  95_thơm sạch_sạch thơm_thơm sạch sẽ_thơm sạch ...
# 97      96     16  96_sản phẩm mô tả_sản phẩm miêu tả_mô tả sản p...
# 98      97     16  97_sản phẩm xài ok_sản phẩm xài_sản phẩm sài o...
# 99      98     16                                98_tẩy_ỷgh_thốn_tốy
# 100     99     15  99_đóng gói cẩn thận_hài lòng sản phẩm_. hài l...
#
#                                         Representation  \
# 0    [đóng gói cẩn thận, cẩn thận ,, cẩn thận, rửa ...
# ...

# %%
topic_model.visualize_topics()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/miniconda3/envs/datascience/lib/python3.10/site-packages/IPython/core/formatters.py:925, in IPythonDisplayFormatter.__call__(self, obj)
#     923 method = get_real_method(obj, self.print_method)
#     924 if method is not None:
# --> 925     method()
#     926     return True
#
# File ~/miniconda3/envs/datascience/lib/python3.10/site-packages/plotly/basedatatypes.py:832, in BaseFigure._ipython_display_(self)
#     829 import plotly.io as pio
#     831 if pio.renderers.render_on_display and pio.renderers.default:
# --> 832     pio.show(self)
#     833 else:
#     834     print(repr(self))
#
# File ~/miniconda3/envs/datascience/lib/python3.10/site-packages/plotly/io/_renderers.py:394, in show(fig, renderer, validate, **kwargs)
#     389         raise ValueError(
# ...
